# %% [markdown]
# # Практическая работа №2: Исследование задач о раскрасках
#
# Выполнил студент гр. 9304 Прокофьев Михаил, вариант 37.

# %% [markdown]
# ## Цель работы
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.

# %% [markdown]
# ## Основные теоретические положения
#
# **Определение 1:**
#
# Орбита элемента $x \in X$ под действием $G$ - это множество $Gx = \{gx | g \in G\}$, где численность элементов в ней предполагает её длину.
#
# При этом, две орбиты не могут пересекаться, либо они должны совпадать, из чего  множество $A$ разбивается в дизъюнктивное объединение орбит.
#
# **Определение 2:**
#
# Cимметрическая группа на некотором множестве $A$ - это множество всех биективных функций с $X \to X$ с операцией композиции.
#
# Обозначается следующим образом: $S_{X}$
#
# **Определение 3:**
#
# Раскраска некоторого множества $A$ - это функция отображения из $A$ в некоторое множество цветов $C$.
#
# Обозначается следующим образом: $C^{I}$
#
# **Определение 4:**
#
# Предположим $G$ - это группа, имеющая нейтральный элемент $e$, а $A$ - множество.
#
# Пусть задана операция $G \times X \to X$, со свойствами: $ex = x$; $g(hx) = (gh)x$  (при этом $gx$ является образом пары $(g,x)$)
#
# Тогда $G$ действует на $A$.
#
#
# **Теорема 1:**
#
# Количество орбит действия группы $G$ на множестве $X$ равно:
#
# $\frac{1}{|G|}\sum_{g \in G} |X^{g}|$
#
#
# **Лемма 1:**
#
# Пусть $G$ группа, действующая на множестве $I$. Тогда формула $gf(i) = f(g^{-1}i)$, где $g \in G$, $i \in I$, а $f \in C^{I}$ задает действие $G$ на $C^{I}$.
#
# **Лемма 2:**
#
# Для элемента $g \in G$ и функции $f \in C^{I}$ следующие условия эквивалентны: $gf = f$; $f(i) = f(g^{n}i)$, $\forall i \in I $ и $n \in \mathbb{Z}$, при этом $i,j \in I$ лежат в одном цикле в циклической записи перестановки $\varphi(g)$, то $f(i) = f(j)$

# %% [markdown]
# ## Постановка задачи
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры SageMath. Полученные результаты содержательно проинтерпретировать.
#
# **Вариант 37**
#
# Сколькими способами можно раскрасить грани тетраэдра, используя краски 5 цветов (с точностью до поворотов тетраэдра)

# %% [markdown]
# ## Порядок выполнения работы
# 1. Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
# 2. Реализовать средствами SageMath функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
# 3. Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.

# %% [markdown]
# ## Выполнение работы

# %%
new_colors = [colors[0], colors[3], colors[1], colors[2]]
new_T1 = create_tetrahedron(new_colors)
T.show()
new_T1.show()

# %% [markdown]
# ## Выводы
# В ходе выполнения практической работы были получены навыки работы с SageMath и оформления отчётов в Jupyter Notebook.
